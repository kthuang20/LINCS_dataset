# %%
# import necessary packages
import cmapPy.pandasGEXpress.GCToo as GCToo
from cmapPy.pandasGEXpress.parse import parse
import cmapPy.pandasGEXpress.subset_gctoo as sg

import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Select only the 978 landmark genes and all the samples that had a high transcriptional response to drug compounds

# %% [markdown]
# #### *1. Select the 978 landmark gene ids to extract from .gctx file*

# %%
# read gene info from gene_info metadata
file_path = "/home/katie_huang_student_uml_edu/LINCS_dataset/GSE70138_Broad_LINCS_gene_info_2017-03-06.txt"
gene_info = pd.read_csv(file_path, sep="\t", dtype=str)
gene_info.head()
# Out:
#   pr_gene_id pr_gene_symbol                                pr_gene_title  \
# 0        780           DDR1  discoidin domain receptor tyrosine kinase 1
# 1       7849           PAX8                                 paired box 8
# 2       2978         GUCA1A               guanylate cyclase activator 1A
# 3       2049          EPHB3                              EPH receptor B3
# 4       2101          ESRRA              estrogen related receptor alpha
#
#   pr_is_lm pr_is_bing
# 0        1          1
# 1        1          1
# 2        0          0
# 3        0          1
# 4        0          1

# %%
# select the ids of only the landmark genes
lm_gene_id = gene_info["pr_gene_id"][gene_info["pr_is_lm"] == "1"]

# check that I have the 978 landmark genes
print(len(lm_gene_id))
# Out:
# 978

# %% [markdown]
# #### *2. Filter out only the trt_cp data using GSE70138_Broad_LINCS_sig_info.txt and save into trt_cps_sig_info.txt with the command line:*
# ``` bash
# grep trt_cp GSE70138_Broad_LINCS_sig_info.txt | cut -f-3,5-8 > trt_cps.txt
# head -1 GSE70138_Broad_LINCS_sig_info.txt | cut -f-3,5-8 > column_names_sig_info.txt
# cat column_names_sig_info.txt trt_cps.txt > trt_cps_sig_info.txt
# rm column_names_sig_info.txt trt_cps.txt
# ```

# %% [markdown]
# ## Select the gene signatures ids of compounds of interest

# %% [markdown]
# #### *1. Select all gene signature info with MCF7*

# %%
# read the gene signature info
file_path = "/home/katie_huang_student_uml_edu/LINCS_dataset/trt_cps_sig_info.txt"
sig_info = pd.read_csv(file_path, sep="\t", dtype=str)
sig_info.set_index("sig_id", inplace=True)

# %%
# select only the gene signature ids with MCF7
MCF7_sig_info = sig_info[sig_info['cell_id'] == 'MCF7']
MCF7_sig_info.head(10)
# Out:
#                            pert_id pert_iname cell_id pert_idose pert_itime  \
# sig_id
# LJP005_MCF7_24H:A07  BRD-K76908866  CP-724714    MCF7    10.0 um       24 h
# LJP005_MCF7_24H:A08  BRD-K76908866  CP-724714    MCF7    3.33 um       24 h
# LJP005_MCF7_24H:A09  BRD-K76908866  CP-724714    MCF7    1.11 um       24 h
# LJP005_MCF7_24H:A10  BRD-K76908866  CP-724714    MCF7    0.37 um       24 h
# LJP005_MCF7_24H:A11  BRD-K76908866  CP-724714    MCF7    0.12 um       24 h
# LJP005_MCF7_24H:A12  BRD-K76908866  CP-724714    MCF7    0.04 um       24 h
# LJP005_MCF7_24H:A13  BRD-K85606544  neratinib    MCF7    10.0 um       24 h
# LJP005_MCF7_24H:A14  BRD-K85606544  neratinib    MCF7    3.33 um       24 h
# LJP005_MCF7_24H:A15  BRD-K85606544  neratinib    MCF7    1.11 um       24 h
# LJP005_MCF7_24H:A16  BRD-K85606544  neratinib    MCF7    0.37 um       24 h
#
#                                                              distil_id
# sig_id
# LJP005_MCF7_24H:A07  LJP005_MCF7_24H_X1_B17:A07|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A08  LJP005_MCF7_24H_X1_B17:A08|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A09  LJP005_MCF7_24H_X1_B17:A09|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A10  LJP005_MCF7_24H_X1_B17:A10|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A11  LJP005_MCF7_24H_X1_B17:A11|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A12  LJP005_MCF7_24H_X1_B17:A12|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A13  LJP005_MCF7_24H_X1_B17:A13|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A14  LJP005_MCF7_24H_X1_B17:A14|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A15  LJP005_MCF7_24H_X1_B17:A15|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A16  LJP005_MCF7_24H_X1_B17:A16|LJP005_MCF7_24H_X2_...

# %%
# total number of gene signatures
len(MCF7_sig_info)
# Out:
# 12737

# %% [markdown]
# #### *2. From these gene signatures, select only those with very high transcriptional responses (TAS > 0.4)*

# %% [markdown]
# ##### a. Add the TAS scores to the sig_id info

# %%
# read the TAS scores of the gene signatures
file_path = "LINCS_dataset/all_data/GSE70138_Broad_LINCS_sig_metrics_2017-03-06.txt"
tas_trt_cps = pd.read_table(file_path, index_col=0)
tas_trt_cps.set_index('sig_id', inplace=True)

# get the tas scores of samples treated with MCF7
MCF7_tas = tas_trt_cps.loc[MCF7_sig_info.index, 'tas']
MCF7_tas.head(10)
# Out:
# /home/katie_huang_student_uml_edu/.conda/envs/CMapPy_env/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# sig_id
# LJP005_MCF7_24H:A07    0.207429
# LJP005_MCF7_24H:A08    0.303676
# LJP005_MCF7_24H:A09    0.231824
# LJP005_MCF7_24H:A10    0.109656
# LJP005_MCF7_24H:A11    0.244196
# LJP005_MCF7_24H:A12    0.127706
# LJP005_MCF7_24H:A13    0.401658
# LJP005_MCF7_24H:A14    0.306974
# LJP005_MCF7_24H:A15    0.357679
# LJP005_MCF7_24H:A16    0.199386
# Name: tas, dtype: float64

# %%
# add the TAS scores to the sig_info for MCF7
MCF7_trt_cps = pd.concat([MCF7_sig_info, MCF7_tas], axis=1)
MCF7_trt_cps.head(10)
# Out:
#                            pert_id pert_iname cell_id pert_idose pert_itime  \
# sig_id
# LJP005_MCF7_24H:A07  BRD-K76908866  CP-724714    MCF7    10.0 um       24 h
# LJP005_MCF7_24H:A08  BRD-K76908866  CP-724714    MCF7    3.33 um       24 h
# LJP005_MCF7_24H:A09  BRD-K76908866  CP-724714    MCF7    1.11 um       24 h
# LJP005_MCF7_24H:A10  BRD-K76908866  CP-724714    MCF7    0.37 um       24 h
# LJP005_MCF7_24H:A11  BRD-K76908866  CP-724714    MCF7    0.12 um       24 h
# LJP005_MCF7_24H:A12  BRD-K76908866  CP-724714    MCF7    0.04 um       24 h
# LJP005_MCF7_24H:A13  BRD-K85606544  neratinib    MCF7    10.0 um       24 h
# LJP005_MCF7_24H:A14  BRD-K85606544  neratinib    MCF7    3.33 um       24 h
# LJP005_MCF7_24H:A15  BRD-K85606544  neratinib    MCF7    1.11 um       24 h
# LJP005_MCF7_24H:A16  BRD-K85606544  neratinib    MCF7    0.37 um       24 h
#
#                                                              distil_id  \
# sig_id
# LJP005_MCF7_24H:A07  LJP005_MCF7_24H_X1_B17:A07|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A08  LJP005_MCF7_24H_X1_B17:A08|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A09  LJP005_MCF7_24H_X1_B17:A09|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A10  LJP005_MCF7_24H_X1_B17:A10|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A11  LJP005_MCF7_24H_X1_B17:A11|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A12  LJP005_MCF7_24H_X1_B17:A12|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A13  LJP005_MCF7_24H_X1_B17:A13|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A14  LJP005_MCF7_24H_X1_B17:A14|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A15  LJP005_MCF7_24H_X1_B17:A15|LJP005_MCF7_24H_X2_...
# LJP005_MCF7_24H:A16  LJP005_MCF7_24H_X1_B17:A16|LJP005_MCF7_24H_X2_...
#
#                           tas
# sig_id
# LJP005_MCF7_24H:A07  0.207429
# LJP005_MCF7_24H:A08  0.303676
# LJP005_MCF7_24H:A09  0.231824
# LJP005_MCF7_24H:A10  0.109656
# LJP005_MCF7_24H:A11  0.244196
# LJP005_MCF7_24H:A12  0.127706
# LJP005_MCF7_24H:A13  0.401658
# LJP005_MCF7_24H:A14  0.306974
# LJP005_MCF7_24H:A15  0.357679
# LJP005_MCF7_24H:A16  0.199386

# %%
# total of number of compounds with tas scores
len(MCF7_trt_cps)
# Out:
# 12737

# %% [markdown]
# ##### b. Sort TAS scores in descending order and select only those where TAS > 0.4

# %%
# sort the TAS scores in descending order
top_trt_cps = MCF7_trt_cps.sort_values(by='tas', ascending=False)
top_trt_cps['tas'] = top_trt_cps['tas'].astype(float)

# select only the ones with very high response (TAS > 0.4)
high_tas_trt_cps = top_trt_cps[top_trt_cps['tas'] > 0.6]

# check that the table ends at 0.4
high_tas_trt_cps.tail(10)
# Out:
#                              pert_id          pert_iname cell_id pert_idose  \
# sig_id
# REP.A027_MCF7_24H:D22  BRD-K93779381    ingenol-mebutate    MCF7    0.37 um
# REP.A008_MCF7_24H:C02  BRD-K36740062         GSK-1070916    MCF7    3.33 um
# REP.A014_MCF7_24H:F04  BRD-K58435339            AT-13387    MCF7    0.37 um
# REP.A015_MCF7_24H:O09  BRD-K61195623  combretastatin-A-4    MCF7    1.11 um
# LJP008_MCF7_24H:I19    BRD-K52560704          methylstat    MCF7    10.0 um
# REP.A021_MCF7_24H:J12  BRD-K83837640        JNJ-26481585    MCF7    0.04 um
# REP.A002_MCF7_24H:K07  BRD-K60230970              MG-132    MCF7    20.0 um
# LJP008_MCF7_24H:M23    BRD-K82181189            ischemin    MCF7    0.12 um
# LJP008_MCF7_24H:I07    BRD-K16485616        mocetinostat    MCF7    10.0 um
# LJP007_MCF7_24H:P24    BRD-K42728290          NVP-BGJ398    MCF7    0.04 um
#
#                       pert_itime  \
# sig_id
# REP.A027_MCF7_24H:D22       24 h
# REP.A008_MCF7_24H:C02       24 h
# REP.A014_MCF7_24H:F04       24 h
# REP.A015_MCF7_24H:O09       24 h
# LJP008_MCF7_24H:I19         24 h
# REP.A021_MCF7_24H:J12       24 h
# REP.A002_MCF7_24H:K07       24 h
# LJP008_MCF7_24H:M23         24 h
# LJP008_MCF7_24H:I07         24 h
# LJP007_MCF7_24H:P24         24 h
#
#                                                                distil_id  \
# sig_id
# REP.A027_MCF7_24H:D22  REP.A027_MCF7_24H_X1_B25:D22|REP.A027_MCF7_24H...
# REP.A008_MCF7_24H:C02  REP.A008_MCF7_24H_X1_B24:C02|REP.A008_MCF7_24H...
# REP.A014_MCF7_24H:F04  REP.A014_MCF7_24H_X1_B23:F04|REP.A014_MCF7_24H...
# REP.A015_MCF7_24H:O09  REP.A015_MCF7_24H_X2_B23:O09|REP.A015_MCF7_24H...
# LJP008_MCF7_24H:I19    LJP008_MCF7_24H_X1_B20:I19|LJP008_MCF7_24H_X2_...
# REP.A021_MCF7_24H:J12  REP.A021_MCF7_24H_X1_B23:J12|REP.A021_MCF7_24H...
# REP.A002_MCF7_24H:K07  REP.A002_MCF7_24H_X1_B27:K07|REP.A002_MCF7_24H...
# LJP008_MCF7_24H:M23    LJP008_MCF7_24H_X1_B20:M23|LJP008_MCF7_24H_X2_...
# LJP008_MCF7_24H:I07    LJP008_MCF7_24H_X1_B20:I07|LJP008_MCF7_24H_X2_...
# LJP007_MCF7_24H:P24    LJP007_MCF7_24H_X1_B20:P24|LJP007_MCF7_24H_X2_...
#
#                             tas
# sig_id
# REP.A027_MCF7_24H:D22  0.603704
# REP.A008_MCF7_24H:C02  0.603602
# REP.A014_MCF7_24H:F04  0.603585
# REP.A015_MCF7_24H:O09  0.603060
# LJP008_MCF7_24H:I19    0.602653
# REP.A021_MCF7_24H:J12  0.602398
# REP.A002_MCF7_24H:K07  0.601651
# LJP008_MCF7_24H:M23    0.600971
# LJP008_MCF7_24H:I07    0.600766
# LJP007_MCF7_24H:P24    0.600068

# %% [markdown]
# ##### c. For each unique compound, select the sample with the highest TAS score

# %%
# create a list to store the sig ids of all the samples with that highest tas scores
highest_tas_sig_ids = []

# group the data by the name of the compound
by_cps = high_tas_trt_cps.groupby("pert_iname")

# store the compound names and their sig ids in a dictionary
cp2samples = by_cps.groups

# look at each compound names and the sig ids for that compound
for cp_name, sig_ids in cp2samples.items():
    # obtain the dataframe with that data
    data = high_tas_trt_cps.loc[sig_ids]
    
    # sort the data by highest tas
    tas_sorted = data.sort_values('tas', ascending=False)

    # obtain the data for the sample with the highest tas scores
    highest_tas = tas_sorted.iloc[0]
    
    # add the sig id to the running list
    highest_tas_sig_ids.append(highest_tas.name)

# create a dataframe containing the tas score for each unique compound whose TAS > 0.4
samples2compare = high_tas_trt_cps.loc[highest_tas_sig_ids]
samples2compare.head(10)
# Out:
#                              pert_id          pert_iname cell_id pert_idose  \
# sig_id
# REP.A022_MCF7_24H:I01  BRD-K71281111            SNX-2112    MCF7    10.0 um
# REP.A008_MCF7_24H:A09  BRD-A68009927        daunorubicin    MCF7    1.11 um
# REP.A011_MCF7_24H:J05  BRD-K06335600          tizanidine    MCF7    0.12 um
# REP.A025_MCF7_24H:P03  BRD-K79131256         albendazole    MCF7    1.11 um
# LJP006_MCF7_24H:H14    BRD-K43389698          BMS-387032    MCF7    3.33 um
# REP.A021_MCF7_24H:J09  BRD-K83837640        JNJ-26481585    MCF7    1.11 um
# REP.A018_MCF7_24H:J20  BRD-K64925568             AMG-232    MCF7    3.33 um
# REP.A015_MCF7_24H:O10  BRD-K61195623  combretastatin-A-4    MCF7    0.37 um
# LJP008_MCF7_24H:A03    BRD-K81418486          vorinostat    MCF7    10.0 um
# REP.A018_MCF7_24H:C07  BRD-K62627508         idasanutlin    MCF7    10.0 um
#
#                       pert_itime  \
# sig_id
# REP.A022_MCF7_24H:I01       24 h
# REP.A008_MCF7_24H:A09       24 h
# REP.A011_MCF7_24H:J05       24 h
# REP.A025_MCF7_24H:P03       24 h
# LJP006_MCF7_24H:H14         24 h
# REP.A021_MCF7_24H:J09       24 h
# REP.A018_MCF7_24H:J20       24 h
# REP.A015_MCF7_24H:O10       24 h
# LJP008_MCF7_24H:A03         24 h
# REP.A018_MCF7_24H:C07       24 h
#
#                                                                distil_id  \
# sig_id
# REP.A022_MCF7_24H:I01  REP.A022_MCF7_24H_X1_B23:I01|REP.A022_MCF7_24H...
# REP.A008_MCF7_24H:A09  REP.A008_MCF7_24H_X1_B24:A09|REP.A008_MCF7_24H...
# REP.A011_MCF7_24H:J05  REP.A011_MCF7_24H_X1_B24:J05|REP.A011_MCF7_24H...
# REP.A025_MCF7_24H:P03  REP.A025_MCF7_24H_X1_B23:P03|REP.A025_MCF7_24H...
# LJP006_MCF7_24H:H14    LJP006_MCF7_24H_X1_B17:H14|LJP006_MCF7_24H_X2_...
# REP.A021_MCF7_24H:J09  REP.A021_MCF7_24H_X1_B23:J09|REP.A021_MCF7_24H...
# REP.A018_MCF7_24H:J20  REP.A018_MCF7_24H_X1_B24:J20|REP.A018_MCF7_24H...
# REP.A015_MCF7_24H:O10  REP.A015_MCF7_24H_X1_B23:O10|REP.A015_MCF7_24H...
# LJP008_MCF7_24H:A03    LJP008_MCF7_24H_X1_B20:A03|LJP008_MCF7_24H_X2_...
# REP.A018_MCF7_24H:C07  REP.A018_MCF7_24H_X1_B24:C07|REP.A018_MCF7_24H...
#
#                             tas
# sig_id
# REP.A022_MCF7_24H:I01  0.722739
# REP.A008_MCF7_24H:A09  0.773276
# REP.A011_MCF7_24H:J05  0.629051
# REP.A025_MCF7_24H:P03  0.654995
# LJP006_MCF7_24H:H14    0.751182
# REP.A021_MCF7_24H:J09  0.781182
# REP.A018_MCF7_24H:J20  0.768454
# REP.A015_MCF7_24H:O10  0.654698
# LJP008_MCF7_24H:A03    0.707743
# REP.A018_MCF7_24H:C07  0.756729

# %% [markdown]
# ## Map the drugs to the diseases

# %% [markdown]
# The diseases related to each drug was taken from the Broad Institute:
# https://repo-hub.broadinstitute.org/repurposing#download-data

# %%
# import the disease information for each drug
file_path = '/home/katie_huang_student_uml_edu/LINCS_dataset/repurposing_drugs_20200324.txt'
disease_info = pd.read_csv(file_path, sep="\t", dtype=str, skiprows=9)

# set the index as the name of the compound
disease_info.set_index('pert_iname', inplace=True)
disease_info.head()
# Out:
#                              clinical_phase                              moa  \
# pert_iname
# (R)-(-)-apomorphine                Launched        dopamine receptor agonist
# (R)-(-)-rolipram                    Phase 1      phosphodiesterase inhibitor
# (R)-baclofen                        Phase 3  benzodiazepine receptor agonist
# (S)-(+)-rolipram                    Phase 1      phosphodiesterase inhibitor
# [sar9,met(o2)11]-substance-p    Preclinical            tachykinin antagonist
#
#                                                                          target  \
# pert_iname
# (R)-(-)-apomorphine           ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...
# (R)-(-)-rolipram                                  PDE4A|PDE4B|PDE4C|PDE4D|PDE5A
# (R)-baclofen                                                      GABBR1|GABBR2
# (S)-(+)-rolipram                                                    PDE4B|PDE4D
# [sar9,met(o2)11]-substance-p                                              TACR1
#
#                                       disease_area           indication
# pert_iname
# (R)-(-)-apomorphine           neurology/psychiatry  Parkinson's Disease
# (R)-(-)-rolipram                               NaN                  NaN
# (R)-baclofen                                   NaN                  NaN
# (S)-(+)-rolipram                               NaN                  NaN
# [sar9,met(o2)11]-substance-p                   NaN                  NaN

# %%
# remove pert_inames where there is no indication (NaN)
disease_info = disease_info[disease_info['indication'].notna()]
disease_info.head(10)
# Out:
#                     clinical_phase  \
# pert_iname
# (R)-(-)-apomorphine       Launched
# abacavir                  Launched
# abamectin                 Launched
# abemaciclib               Launched
# abiraterone               Launched
# abiraterone-acetate       Launched
# acalabrutinib             Launched
# acamprosate               Launched
# acarbose                  Launched
# acebutolol                Launched
#
#                                                             moa  \
# pert_iname
# (R)-(-)-apomorphine                   dopamine receptor agonist
# abacavir             nucleoside reverse transcriptase inhibitor
# abamectin                       benzodiazepine receptor agonist
# abemaciclib                                       CDK inhibitor
# abiraterone                     androgen biosynthesis inhibitor
# abiraterone-acetate             androgen biosynthesis inhibitor
# acalabrutinib          Bruton's tyrosine kinase (BTK) inhibitor
# acamprosate                       glutamate receptor antagonist
# acarbose                                  glucosidase inhibitor
# acebutolol                       adrenergic receptor antagonist
#
#                                                                 target  \
# pert_iname
# (R)-(-)-apomorphine  ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...
# abacavir                                                           NaN
# abamectin                                                GABBR1|GABBR2
# abemaciclib                                                  CDK4|CDK6
# abiraterone                                            CYP11B1|CYP17A1
# abiraterone-acetate                                            CYP17A1
# acalabrutinib                                                      BTK
# acamprosate          GABRA1|GABRA2|GABRA3|GABRA4|GABRA5|GABRA6|GABR...
# acarbose                                                    AMY2A|MGAM
# acebutolol                                                       ADRB1
#
#                                disease_area  \
# pert_iname
# (R)-(-)-apomorphine    neurology/psychiatry
# abacavir                 infectious disease
# abamectin                infectious disease
# abemaciclib                        oncology
# abiraterone                        oncology
# abiraterone-acetate                oncology
# acalabrutinib        hematologic malignancy
# acamprosate            neurology/psychiatry
# acarbose                      endocrinology
# acebutolol                       cardiology
#
#                                                indication
# pert_iname
# (R)-(-)-apomorphine                   Parkinson's Disease
# abacavir             human immunodeficiency virus (HIV-1)
# abamectin                      gastrointestinal parasites
# abemaciclib                                 breast cancer
# abiraterone                               prostate cancer
# abiraterone-acetate                       prostate cancer
# acalabrutinib                  mantle cell lymphoma (MCL)
# acamprosate                       abstinence from alcohol
# acarbose                                diabetes mellitus
# acebutolol           hypertension|ventricular arrhythmias

# %%
# obtain the pert_info data
file_path = '/home/katie_huang_student_uml_edu/LINCS_dataset/GSE70138_Broad_LINCS_pert_info.txt'
pert_info = pd.read_csv(file_path, sep="\t", dtype=str)

# set the index of the dataframe as the pert_iname
pert_info.set_index('pert_iname', inplace=True)
pert_info.head(10)
# Out:
#                                        pert_id  \
# pert_iname
# 10-DEBC                          BRD-K70792160
# phorbol-myristate-acetate        BRD-K68552125
# 16,16-dimethylprostaglandin-e2   BRD-K92301463
# 17-hydroxyprogesterone-caproate  BRD-A29731977
# 2-iminobiotin                    BRD-K07954936
# 2-methoxyestradiol               BRD-K44408410
# 2',5'-dideoxyadenosine           BRD-A20131130
# 3-amino-benzamide                BRD-K08703257
# 3-deazaadenosine                 BRD-A79431551
# 3,3'-diindolylmethane            BRD-K37846922
#
#                                                                   canonical_smiles  \
# pert_iname
# 10-DEBC                                        CCN(CC)CCCCN1c2ccccc2Oc2ccc(Cl)cc12
# phorbol-myristate-acetate        CCCCCCCCCCCCCC(=O)O[C@@H]1[C@@H](C)[C@]2(O)[C@...
# 16,16-dimethylprostaglandin-e2   CCCCC(C)(C)[C@H](O)\C=C\[C@H]1[C@H](O)CC(=O)[C...
# 17-hydroxyprogesterone-caproate  CCCCCC(=O)O[C@@]1(CCC2C3CCC4=CC(=O)CC[C@]4(C)C...
# 2-iminobiotin                             OC(=O)CCCC[C@@H]1SC[C@@H]2NC(=N)N[C@H]12
# 2-methoxyestradiol               COc1cc2[C@H]3CC[C@]4(C)[C@@H](O)CC[C@H]4[C@@H]...
# 2',5'-dideoxyadenosine                                 CC1OC(CC1O)n1cnc2c(N)ncnc12
# 3-amino-benzamide                                                NC(=O)c1cccc(N)c1
# 3-deazaadenosine                          Nc1nccc2n(cnc12)[C@@H]1O[C@H](CO)C(O)C1O
# 3,3'-diindolylmethane                          C(c1c[nH]c2ccccc12)c1c[nH]c2ccccc12
#
#                                                    inchi_key pert_type
# pert_iname
# 10-DEBC                          GYBXAGDWMCJZJK-UHFFFAOYSA-N    trt_cp
# phorbol-myristate-acetate        PHEDXBVPIONUQT-RGYGYFBISA-N    trt_cp
# 16,16-dimethylprostaglandin-e2   QAOBBBBDJSWHMU-WMBBNPMCSA-N    trt_cp
# 17-hydroxyprogesterone-caproate  DOMWKUIIPQCAJU-JKPPDDDBSA-N    trt_cp
# 2-iminobiotin                    WWVANQJRLPIHNS-ZKWXMUAHSA-N    trt_cp
# 2-methoxyestradiol               CQOQDQWUFQDJMK-SSTWWWIQSA-N    trt_cp
# 2',5'-dideoxyadenosine           FFHPXOJTVQDVMO-UHFFFAOYSA-N    trt_cp
# 3-amino-benzamide                GSCPDZHWVNUUFI-UHFFFAOYSA-N    trt_cp
# 3-deazaadenosine                 DBZQFUNLCALWDY-JXACCQRMSA-N    trt_cp
# 3,3'-diindolylmethane            VFTRKSBEFQDZKX-UHFFFAOYSA-N    trt_cp

# %%
# select only the drugs associated with a disease
drug_to_disease = pert_info.merge(disease_info, how='inner', on='pert_iname')
drug_to_disease.head()
# Out:
#                                        pert_id  \
# pert_iname
# 17-hydroxyprogesterone-caproate  BRD-A29731977
# 5-aminolevulinic-acid            BRD-K57631554
# abacavir                         BRD-A95032015
# abiraterone-acetate              BRD-K16133773
# acarbose                         BRD-K01621533
#
#                                                                   canonical_smiles  \
# pert_iname
# 17-hydroxyprogesterone-caproate  CCCCCC(=O)O[C@@]1(CCC2C3CCC4=CC(=O)CC[C@]4(C)C...
# 5-aminolevulinic-acid                                              NCC(=O)CCC(O)=O
# abacavir                                  Nc1nc(NC2CC2)c2ncn(C3C[C@H](CO)C=C3)c2n1
# abiraterone-acetate              CC(=O)O[C@H]1CC[C@]2(C)[C@@H]3CC[C@@]4(C)[C@@H...
# acarbose                         C[C@@H]1O[C@H](O[C@@H]2[C@H](CO)O[C@H](O[C@@H]...
#
#                                                    inchi_key pert_type  \
# pert_iname
# 17-hydroxyprogesterone-caproate  DOMWKUIIPQCAJU-JKPPDDDBSA-N    trt_cp
# 5-aminolevulinic-acid            ZGXJTSGNIOSYLO-UHFFFAOYSA-N    trt_cp
# abacavir                         MCGSCOLBFJQGHM-HNHGDDPOSA-N    trt_cp
# abiraterone-acetate              UVIQSJCZCSLXRZ-HCWFNAMGSA-N    trt_cp
# acarbose                         XUFXOAAUWZOOIT-PCKYEMPFSA-N    trt_cp
#
#                                 clinical_phase  \
# pert_iname
# 17-hydroxyprogesterone-caproate       Launched
# 5-aminolevulinic-acid                 Launched
# abacavir                              Launched
# abiraterone-acetate                   Launched
# acarbose                              Launched
#
#                                                                         moa  \
# pert_iname
# 17-hydroxyprogesterone-caproate               progesterone receptor agonist
# 5-aminolevulinic-acid                                       oxidizing agent
# abacavir                         nucleoside reverse transcriptase inhibitor
# abiraterone-acetate                         androgen biosynthesis inhibitor
# acarbose                                              glucosidase inhibitor
#
#                                                              target  \
# pert_iname
# 17-hydroxyprogesterone-caproate  AR|ESR1|ESR2|NR1H4|NR1I2|NR3C1|PGR
# 5-aminolevulinic-acid                                          ALAD
# abacavir                                                        NaN
# abiraterone-acetate                                         CYP17A1
# acarbose                                                 AMY2A|MGAM
#
#                                           disease_area  \
# pert_iname
# 17-hydroxyprogesterone-caproate  obstetrics/gynecology
# 5-aminolevulinic-acid             oncology|dermatology
# abacavir                            infectious disease
# abiraterone-acetate                           oncology
# acarbose                                 endocrinology
#
#                                                            indication
# pert_iname
# 17-hydroxyprogesterone-caproate             spontaneous preterm birth
# 5-aminolevulinic-acid                   glioma|actinic keratosis (AK)
# abacavir                         human immunodeficiency virus (HIV-1)
# abiraterone-acetate                                   prostate cancer
# acarbose                                            diabetes mellitus

# %%
# calculate the total number of drugs associated with a disease
len(drug_to_disease)
# Out:
# 884

# %%
# sort the drugs by their disease area and disease indication
drug_to_disease = drug_to_disease.sort_values(by=['disease_area', 'indication'])
drug_to_disease.head()
# Out:
#                                    pert_id  \
# pert_iname
# acrivastine                  BRD-K50163129
# beclomethasone-dipropionate  BRD-A11319535
# ciclesonide                  BRD-K35245662
# clemizole                    BRD-K04704168
# diphenylpyraline             BRD-K22936972
#
#                                                               canonical_smiles  \
# pert_iname
# acrivastine                    Cc1ccc(cc1)C(=C/CN1CCCC1)\c1cccc(\C=C\C(O)=O)n1
# beclomethasone-dipropionate  CCC(=O)OCC(=O)C1(OC(=O)CC)C(C)CC2C3CCC4=CC(=O)...
# ciclesonide                  CC(C)C(=O)OCC(=O)[C@@]12O[C@@H](O[C@@H]1C[C@H]...
# clemizole                                 Clc1ccc(Cn2c(CN3CCCC3)nc3ccccc23)cc1
# diphenylpyraline                               CN1CCC(CC1)OC(c1ccccc1)c1ccccc1
#
#                                                inchi_key pert_type  \
# pert_iname
# acrivastine                  PWACSDKDOHSSQD-IUTFFREVSA-N    trt_cp
# beclomethasone-dipropionate  KUVIULQEHSCUHY-UHFFFAOYSA-N    trt_cp
# ciclesonide                  LUKZNWIVRBCLON-GXOBDPJESA-N    trt_cp
# clemizole                    CJXAEXPPLWQRFR-UHFFFAOYSA-N    trt_cp
# diphenylpyraline             OWQUZNMMYNAXSL-UHFFFAOYSA-N    trt_cp
#
#                             clinical_phase                              moa  \
# pert_iname
# acrivastine                       Launched    histamine receptor antagonist
# beclomethasone-dipropionate       Launched  glucocorticoid receptor agonist
# ciclesonide                       Launched  glucocorticoid receptor agonist
# clemizole                         Launched                    HCV inhibitor
# diphenylpyraline                  Launched      dopamine reuptake inhibitor
#
#                                      target disease_area         indication
# pert_iname
# acrivastine                            HRH1      allergy  allergic rhinitis
# beclomethasone-dipropionate     GPR97|NR3C1      allergy  allergic rhinitis
# ciclesonide                  NR3C1|SERPINA6      allergy  allergic rhinitis
# clemizole                               NaN      allergy  allergic rhinitis
# diphenylpyraline                HRH1|SLC6A3      allergy  allergic rhinitis

# %% [markdown]
# ## Select drugs to compare based on these disease indications

# %% [markdown]
# #### *1. Show only the compounds that have high TAS scores with a drug indication*

# %%
# select all the samples with high TAS scores treated with MCF7 that have a disease associated with it
test_samples = samples2compare[samples2compare['pert_iname'].isin(drug_to_disease.index)]

# unique compound ids with associated diseases
unique_cp_ids = test_samples['pert_id'].unique()

# %%
unique_cp_ids
# Out:
# array(['BRD-A68009927', 'BRD-K06335600', 'BRD-K79131256', 'BRD-K81418486',
#        'BRD-A94756469', 'BRD-K73088654', 'BRD-K43586850', 'BRD-A67097164',
#        'BRD-K21361524', 'BRD-A45889380', 'BRD-K14619660', 'BRD-K47869605',
#        'BRD-K50691590', 'BRD-K49350383', 'BRD-K68346641', 'BRD-K55026842',
#        'BRD-K57631554', 'BRD-A33084557', 'BRD-K13646352', 'BRD-K75649340',
#        'BRD-K76674262', 'BRD-K15409150', 'BRD-K56844688', 'BRD-K78659596',
#        'BRD-K93779381', 'BRD-K52020312', 'BRD-K92093830', 'BRD-K92213669',
#        'BRD-K17743125', 'BRD-K89561498', 'BRD-K78485176', 'BRD-K35960502',
#        'BRD-K21680192', 'BRD-K72951360', 'BRD-K15179879', 'BRD-A79768653',
#        'BRD-K77987382', 'BRD-K74717603', 'BRD-K78431006', 'BRD-K57041787',
#        'BRD-A74914197', 'BRD-K61397605', 'BRD-A66419424'], dtype=object)

# %%
# number of unique compounds with associated diseases
len(unique_cp_ids)
# Out:
# 43

# %% [markdown]
# #### *2. Categorize the pert_ids by their indication*

# %%
# list the indication of these compounds
drug2indications = drug_to_disease[['pert_id', 'indication']][drug_to_disease['pert_id'].isin(unique_cp_ids)]
drug2indications
# Out:
#                              pert_id  \
# pert_iname
# digoxin                BRD-A94756469
# lacidipine             BRD-K43586850
# olmesartan-medoxomil   BRD-K78485176
# ingenol-mebutate       BRD-K93779381
# metronidazole          BRD-K52020312
# altrenogest            BRD-K14619660
# lomitapide             BRD-K92213669
# amsacrine              BRD-K68346641
# midostaurin            BRD-K13646352
# thioguanine            BRD-K49350383
# daunorubicin           BRD-A68009927
# tioguanine             BRD-K75649340
# homoharringtonine      BRD-K76674262
# romidepsin             BRD-K61397605
# vorinostat             BRD-K81418486
# carfilzomib            BRD-K15179879
# ixazomib               BRD-K78659596
# ixazomib-citrate       BRD-A66419424
# selinexor              BRD-K21361524
# bortezomib             BRD-K50691590
# belinostat             BRD-K17743125
# pralatrexate           BRD-A74914197
# azacitidine            BRD-K55026842
# doxorubicin            BRD-K92093830
# albendazole            BRD-K79131256
# podophyllotoxin        BRD-K47869605
# mepacrine              BRD-A45889380
# etravirine             BRD-K74717603
# mebendazole            BRD-K77987382
# niclosamide            BRD-K35960502
# tioconazole            BRD-A33084557
# penfluridol            BRD-K15409150
# tizanidine             BRD-K06335600
# dabigatran-etexilate   BRD-K57041787
# mitoxantrone           BRD-K21680192
# valrubicin             BRD-K72951360
# epirubicin             BRD-K56844688
# floxuridine            BRD-K73088654
# SN-38                  BRD-K89561498
# crizotinib             BRD-K78431006
# 5-aminolevulinic-acid  BRD-K57631554
# ifosfamide             BRD-A67097164
# sirolimus              BRD-A79768653
#
#                                                               indication
# pert_iname
# digoxin                congestive heart failure|atrial fibrillation (AF)
# lacidipine                                                  hypertension
# olmesartan-medoxomil                                        hypertension
# ingenol-mebutate                                  actinic keratosis (AK)
# metronidazole                                                    rosacea
# altrenogest                                                       estrus
# lomitapide                                          hypercholesterolemia
# amsacrine                             acute lymphoblastic leukemia (ALL)
# midostaurin                                 acute myeloid leukemia (AML)
# thioguanine                                 acute myeloid leukemia (AML)
# daunorubicin           acute myeloid leukemia (AML)|acute lymphoblast...
# tioguanine             acute myeloid leukemia (AML)|acute lymphoblast...
# homoharringtonine                         chronic myeloid leukemia (CML)
# romidepsin                              cutaneous T-cell lymphoma (CTCL)
# vorinostat                              cutaneous T-cell lymphoma (CTCL)
# carfilzomib                                             multiple myeloma
# ixazomib                                                multiple myeloma
# ixazomib-citrate                                        multiple myeloma
# selinexor                                               multiple myeloma
# bortezomib                   multiple myeloma|mantle cell lymphoma (MCL)
# belinostat                             peripheral T-cell lymphoma (PTCL)
# pralatrexate                           peripheral T-cell lymphoma (PTCL)
# azacitidine            myelodysplastic diseases (MDS)|anemia|chronic ...
# doxorubicin            acute lymphoblastic leukemia (ALL)|acute myelo...
# albendazole            cystic hydatid disease|parenchymal neurocystic...
# podophyllotoxin                                            genital warts
# mepacrine                                                     giardiasis
# etravirine                          human immunodeficiency virus (HIV-1)
# mebendazole                         pinworm|whipworm|hookworm|ascariasis
# niclosamide                                                     tapeworm
# tioconazole                                              yeast infection
# penfluridol                                                schizophrenia
# tizanidine                                                        spasms
# dabigatran-etexilate   stroke|systemic embolism|pulmonary embolism (P...
# mitoxantrone           multiple sclerosis|prostate cancer|acute myelo...
# valrubicin                                                bladder cancer
# epirubicin                                                 breast cancer
# floxuridine                                            colorectal cancer
# SN-38                                                  colorectal cancer
# crizotinib                            non-small cell lung cancer (NSCLC)
# 5-aminolevulinic-acid                      glioma|actinic keratosis (AK)
# ifosfamide                     testicular carcinoma|hemorrhagic cystitis
# sirolimus                       organ rejection|lymphangioleiomyomatosis

# %%
print(drug2indications.loc['bortezomib', 'indication'])
# Out:
# multiple myeloma|mantle cell lymphoma (MCL)

# %% [markdown]
# ## Create pairs of drugs to compare that share or do not share indications

# %% [markdown]
# #### *1. Create pairs of drug ids to compare group by whether they share an indication (are similar)*

# %%
# create an empty dictionary
pairs2compare = {
    'similar drugs': [],
    'different drugs': []
}

# set the pert_id as the index
id2indications = drug2indications.set_index('pert_id')

# obtain all the ids of all the compounds
all_cps = id2indications.index

# look through the indices of the list of unique compounds up until the 2nd last index
for idx, pert_id in enumerate(all_cps):
    # store all the indications of this compound
    indications_str = id2indications.loc[pert_id, 'indication']
    # store all the indications for this compound as set
    indications_set = set(indications_str.split('|'))
    # create a subset of the dataframe containing the remaining compounds
    other_ids = id2indications.iloc[idx+1:]
    # look through each of the remaining compounds
    for i, cp in other_ids.iterrows():
        # store the indications of each compound as a string
        other_cp_indications_str = cp['indication']
        # store the indications of each compound as a set
        other_cp_indications_set = set(other_cp_indications_str.split('|'))
        # determine the same indications across both compounds
        common_indications = indications_set.intersection(other_cp_indications_set)
        # add the pert_ids of the two drugs to the a list 
        cps_pair = [pert_id, i]
        
        # check if there are samples that have been treated with this compound
        cp_ids_in_data = samples2compare['pert_id'].isin(cps_pair)
        # get the data associated with these compounds
        cp_data = samples2compare[cp_ids_in_data]
        
        # if they share indications,
        if common_indications:
            # add this data to the list of similar drugs in the dictionary
            pairs2compare['similar drugs'].append(cp_data)
        # otherwise, they are different drugs
        else:
            # add this data to the list of different drugs in the dictionary
            pairs2compare['different drugs'].append(cp_data)

# check that you have unique pairs of compounds to compare to each other
pairs2compare['similar drugs'][0]
# Out:
#                              pert_id            pert_iname cell_id pert_idose  \
# sig_id
# REP.A007_MCF7_24H:B24  BRD-K43586850            lacidipine    MCF7    0.04 um
# REP.A024_MCF7_24H:M12  BRD-K78485176  olmesartan-medoxomil    MCF7    0.04 um
#
#                       pert_itime  \
# sig_id
# REP.A007_MCF7_24H:B24       24 h
# REP.A024_MCF7_24H:M12       24 h
#
#                                                                distil_id  \
# sig_id
# REP.A007_MCF7_24H:B24  REP.A007_MCF7_24H_X1_B22:B24|REP.A007_MCF7_24H...
# REP.A024_MCF7_24H:M12  REP.A024_MCF7_24H_X1_B23:M12|REP.A024_MCF7_24H...
#
#                             tas
# sig_id
# REP.A007_MCF7_24H:B24  0.666125
# REP.A024_MCF7_24H:M12  0.645101

# %%
# find the total number of pairs of similar drugs
len(pairs2compare['similar drugs'])
# Out:
# 41

# %%
# find the total number of pairs of different drugs
len(pairs2compare['different drugs'])
# Out:
# 862

# %% [markdown]
# #### *2. Select the gene signatures for each pair*

# %%
# read the LINCS Level 5 dataset
file_path = "/home/katie_huang_student_uml_edu/LINCS_dataset/LINCS_dataset.gctx"

# select only the landmark gene of drug compounds of interest
gene_sigs = parse(file_path, rid=lm_gene_id, cid=samples2compare.index)

# get the metadata for one of the pairs
pair_metadata = pairs2compare['similar drugs'][0]

# get the sig ids for one of the pairs to compare
pair_ids = list(pair_metadata.index.values)

# get the signatures of only those two compounds
pair_gene_sigs = sg.subset_gctoo(gene_sigs, cid=pair_ids)

# create a new GCTOO object with all the metadata for each sample
sig_info = GCToo.GCToo(data_df=pair_gene_sigs.data_df.copy(), 
                       row_metadata_df=pair_gene_sigs.row_metadata_df.copy(), 
                       col_metadata_df=pair_metadata.copy(), 
                       make_multiindex=True)

sig_info.multi_index_df[:5]
# Out:
# pert_id                                                                                BRD-K43586850  \
# pert_iname                                                                                lacidipine
# cell_id                                                                                         MCF7
# pert_idose                                                                                   0.04 um
# pert_itime                                                                                      24 h
# distil_id  REP.A007_MCF7_24H_X1_B22:B24|REP.A007_MCF7_24H_X2_B22:B24|REP.A007_MCF7_24H_X3.A2_B23:B24
# tas                                                                                         0.666125
# cid                                                                            REP.A007_MCF7_24H:B24
# rid
# 0                                                   -1.458264
# 1                                                    0.301619
# 2                                                   -1.872412
# 3                                                   -0.253713
# 4                                                    0.114259
#
# pert_id                                                                             BRD-K78485176
# pert_iname                                                                   olmesartan-medoxomil
# cell_id                                                                                      MCF7
# pert_idose                                                                                0.04 um
# pert_itime                                                                                   24 h
# distil_id  REP.A024_MCF7_24H_X1_B23:M12|REP.A024_MCF7_24H_X2_B23:M12|REP.A024_MCF7_24H_X3_B23:M12
# tas                                                                                      0.645101
# cid                                                                         REP.A024_MCF7_24H:M12
# rid
# 0                                                   -1.203949
# 1                                                   -0.305805
# 2                                                   -2.626505
# 3                                                    1.143355
# 4                                                    3.084725

# %%
# creating a function to create a dataframe containing the gene signatures of the pert_ids of interest
def select_gene_sigs(lm_gene_id, gene_sigs, pair_metadata):
    # get the sig ids for one of the pairs to compare
    pair_ids = list(pair_metadata.index.values)

    # get the signatures of only those two compounds
    pair_gene_sigs = sg.subset_gctoo(gene_sigs, cid=pair_ids)

    # create a new GCTOO object with all the metadata for each sample
    sig_info = GCToo.GCToo(data_df=pair_gene_sigs.data_df.copy(), 
                           row_metadata_df=pair_gene_sigs.row_metadata_df.copy(), 
                           col_metadata_df=pair_metadata.copy(), 
                           make_multiindex=True)
    return sig_info

# %%
# check that the function is working using one pair of similar drugs
test_pair = pairs2compare['similar drugs'][0]
sig_info = select_gene_sigs(lm_gene_id, gene_sigs, test_pair)
sig_info.multi_index_df[:5]
# Out:
# pert_id                                                                                BRD-K43586850  \
# pert_iname                                                                                lacidipine
# cell_id                                                                                         MCF7
# pert_idose                                                                                   0.04 um
# pert_itime                                                                                      24 h
# distil_id  REP.A007_MCF7_24H_X1_B22:B24|REP.A007_MCF7_24H_X2_B22:B24|REP.A007_MCF7_24H_X3.A2_B23:B24
# tas                                                                                         0.666125
# cid                                                                            REP.A007_MCF7_24H:B24
# rid
# 0                                                   -1.458264
# 1                                                    0.301619
# 2                                                   -1.872412
# 3                                                   -0.253713
# 4                                                    0.114259
#
# pert_id                                                                             BRD-K78485176
# pert_iname                                                                   olmesartan-medoxomil
# cell_id                                                                                      MCF7
# pert_idose                                                                                0.04 um
# pert_itime                                                                                   24 h
# distil_id  REP.A024_MCF7_24H_X1_B23:M12|REP.A024_MCF7_24H_X2_B23:M12|REP.A024_MCF7_24H_X3_B23:M12
# tas                                                                                      0.645101
# cid                                                                         REP.A024_MCF7_24H:M12
# rid
# 0                                                   -1.203949
# 1                                                   -0.305805
# 2                                                   -2.626505
# 3                                                    1.143355
# 4                                                    3.084725

# %%
## automate the process of selecting the gene signatures for each pair
# create an empty dictionary to store the gene signatures of each pair
pairs_sig_info = {
    'similar drugs': [],
    'different drugs': []
}

# look at each group drugs (similar vs different)
for group in pairs2compare:
    # get all the pairs in group
    pairs_in_group = pairs2compare[group]
    # look at each pair of compounds in each group
    for pair_of_cps in pairs_in_group:
        # select the sig_info for these compounds
        sig_info = select_gene_sigs(lm_gene_id, gene_sigs, pair_of_cps)
        # add this sig info to the correct group of the new dictionary
        pairs_sig_info[group].append(sig_info)

# check that automating process was correct
test_pair = pairs_sig_info['similar drugs'][0]
test_pair.multi_index_df[:5]
# Out:
# pert_id                                                                                BRD-K43586850  \
# pert_iname                                                                                lacidipine
# cell_id                                                                                         MCF7
# pert_idose                                                                                   0.04 um
# pert_itime                                                                                      24 h
# distil_id  REP.A007_MCF7_24H_X1_B22:B24|REP.A007_MCF7_24H_X2_B22:B24|REP.A007_MCF7_24H_X3.A2_B23:B24
# tas                                                                                         0.666125
# cid                                                                            REP.A007_MCF7_24H:B24
# rid
# 0                                                   -1.458264
# 1                                                    0.301619
# 2                                                   -1.872412
# 3                                                   -0.253713
# 4                                                    0.114259
#
# pert_id                                                                             BRD-K78485176
# pert_iname                                                                   olmesartan-medoxomil
# cell_id                                                                                      MCF7
# pert_idose                                                                                0.04 um
# pert_itime                                                                                   24 h
# distil_id  REP.A024_MCF7_24H_X1_B23:M12|REP.A024_MCF7_24H_X2_B23:M12|REP.A024_MCF7_24H_X3_B23:M12
# tas                                                                                      0.645101
# cid                                                                         REP.A024_MCF7_24H:M12
# rid
# 0                                                   -1.203949
# 1                                                   -0.305805
# 2                                                   -2.626505
# 3                                                    1.143355
# 4                                                    3.084725

# %% [markdown]
# ## Perform Spearman correlations for all pairs of drugs

# %%
# function to create a scatter plot for each drug dosage comparing 2 drug compounds
def spearman_correlation(pair_of_sigs):
    # make a scatterplot 
    #sns.scatterplot(
        #x = pair_of_sigs.data_df.iloc[:, 0],
        #y = pair_of_sigs.data_df.iloc[:, 1]
    #)
    # label x-axis of the scatterplot with the compound name
    #plt.xlabel(pair_of_sigs.col_metadata_df.iloc[0].pert_iname)
    # label y-axis of the scatterplot with the compound name
    #plt.ylabel(pair_of_sigs.col_metadata_df.iloc[1].pert_iname)
    # label title with dose being compared at
    #plt.title(pair_of_sigs.col_metadata_df.iloc[0].pert_idose)
    #plt.show()

    # perform a spearman correlation
    spearman_corr, p_value = stats.spearmanr(pair_of_sigs.data_df.iloc[:, 0], pair_of_sigs.data_df.iloc [:,1])
    #print('Spearman Correlation:', spearman_corr, 'p value:', p_value)
    return spearman_corr, p_value

# %% [markdown]
# #### *1. Compare all pairs of drugs that share the same indication (are similar)*

# %%
# create a dictionary to store the spearman correlations and their respective p values
spearman_corrs = {
    'spearman correlation': [],
    'p value': [],
    'share an indication': []
}

# store all the pairs of drugs that share an indication in a list
similar_pairs = pairs_sig_info['similar drugs']

# for each pair of drugs that share an indication,
for pair in similar_pairs:
    # make a scatter plot and perform a spearman correlation and store the correlation and p values
    corr, p = spearman_correlation(pair)
    
    # add the correlation to the running list of all spearman correlations
    spearman_corrs['spearman correlation'].append(corr)
    
    # add the p value to the running list of all p values
    spearman_corrs['p value'].append(p)
    
    # indicate they share an indication
    spearman_corrs['share an indication'].append('share an indication')

# %% [markdown]
# #### *2. Compare pairs of drugs that do not share an indication (are different)*

# %%
# store all the pairs of drugs that share an indication in a list
diff_pairs = pairs_sig_info['different drugs']

# for each pair of drugs that share an indication,
for pair in diff_pairs:
    # make a scatter plot and perform a spearman correlation and store the correlation and p values
    corr, p = spearman_correlation(pair)
    
    # add the correlation to the running list of all spearman correlations
    spearman_corrs['spearman correlation'].append(corr)
    
    # add the p value to the running list of all p values
    spearman_corrs['p value'].append(p)
    
    # indicate that the two drugs do not share an indication
    spearman_corrs['share an indication'].append('do not share an indication')

# %%
# convert the dictionary into a dataframe
spearman_corrs_df = pd.DataFrame(spearman_corrs)
spearman_corrs_df.head(10)
# Out:
#         p value  share an indication  spearman correlation
# 0  4.533875e-13  share an indication              0.228683
# 1  2.476888e-48  share an indication              0.443274
# 2  8.072025e-37  share an indication              0.389688
# 3  1.770784e-59  share an indication              0.487350
# 4  3.639375e-33  share an indication              0.370399
# 5  6.879097e-01  share an indication              0.012861
# 6  1.310416e-28  share an indication              0.344347
# 7  2.400065e-01  share an indication              0.037606
# 8  1.158792e-38  share an indication              0.398949
# 9  9.617408e-11  share an indication              0.205038

# %%
# create a new figure for the histograms with specified sizes
plt.figure(figsize=(10,10))

# set a grid on the histograms
sns.set(style='whitegrid')

# create a histogram of all spearman correlations for pairs of similar drugs
sns.violinplot(data=spearman_corrs, x='share an indication', y='spearman correlation', inner='box', common_norm=False)

# Customize the plot
plt.title("MCF7")
plt.ylabel("Spearman correlations")

# Show the plot
plt.show()
